# %% [markdown]
# # Lab 7

# %% [markdown]
# ![machine.png](attachment:machine.png)

# %% [markdown]
# ## Задача: Написать программу нечеткого управления автомобилем
# ## для левого и правого поворота

# %% [markdown]
# ![m_muL.png](attachment:m_muL.png)

# %% [markdown]
# ### Функции принадлежности для определения положения цели и угла на который надо повернуть

# %% [markdown]
# ![m_gogen.png](attachment:m_gogen.png)

# %% [markdown]
# ### Импликация Гогена

# %% [markdown]
# ![m_gogen2.png](attachment:m_gogen2.png)

# %% [markdown]
# ### Результируюшая формула

# %% [markdown]
# ![m_result.png](attachment:m_result.png)

# %%
import math
import numpy as np
sigma = 10
def fuzzy_coor(x,_X):
    return max(0,1-math.pow((x-_X)/sigma,2))
for x in np.linspace(980,1020):
    print(x,fuzzy_coor(x,1000))
# Out:
# 980.0 0
# 980.816326531 0
# 981.632653061 0
# 982.448979592 0
# 983.265306122 0
# 984.081632653 0
# 984.897959184 0
# 985.714285714 0
# 986.530612245 0
# 987.346938776 0
# 988.163265306 0
# 988.979591837 0
# 989.795918367 0
# 990.612244898 0.11870054144106135
# 991.428571429 0.26530612244898233
# 992.244897959 0.39858392336525594
# 993.06122449 0.5185339441899188
# 993.87755102 0.6251561849229521
# 994.693877551 0.7184506455643436
# 995.510204082 0.798417326114119
# 996.326530612 0.8650562265722644
# 997.142857143 0.9183673469387736
# 997.959183673 0.9583506872136613
# 998.775510204 0.9850062473969192
# 999.591836735 0.9983340274885463
# 1000.40816327 0.9983340274885463
# 1001.2244898 0.9850062473969192
# 1002.04081633 0.9583506872136613
# 1002.85714286 0.9183673469387736
# 1003.67346939 0.8650562265722644
# 1004.48979592 0.798417326114119
# 1005.30612245 0.7184506455643436
# 1006.12244898 0.6251561849229521
# 1006.93877551 0.5185339441899188
# 1007.75510204 0.39858392336525594
# ...

# %%
import numpy as np
import math
from skimage import draw

X_car = 0
Y_car = np.random.random()*1000
speed_car = 20
angle_car = -math.pi/4
# Loop until X_car >= X_target:
rr, cc = draw.circle_perimeter(1000, 1000, radius=80)
print("Here we go")
for pair in zip(rr,cc):
    pass
    #print(pair)
# Out:
# Here we go
